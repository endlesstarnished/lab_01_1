# %%
# Задание task_01_01.
""" Составьте программу, которая запрашивает у пользователя 2 целых числа и выполняет операции:
•	арифметические: +, -, * , / , // , %, **;
•	сравнение: <, <=, >, >=, !=, ==,
выводя на экран результат каждого действия. В случае получение вещественного результата, округлите его до 2-х знаков после запятой (используя функцию round()).
"""
# Выполнил: Миленин И.Д.
# Группа: АБП-231


a = int(input("a = "))
b = int(input("b = "))

print("Сумма =", a + b)

print("Разность =", a - b)

print("Произведение =", a * b)

print("Частное =", round(a / b, 2))

print("Деление нацело =", a // b)

print("Остаток от деления =", a % b)

print(a < b)
if a < b:
  print("Неравенство верно, а меньше б")
else:
  print("Неравенство неверно, а больше б")

print(a <= b)
if a <= b:
  print("Неравенство верно, а меньше или равняется б")
else:
  print("Неравенство неверно, а больше б")

print(a > b)
if a > b:
  print("Неравенство верно, а больше б")
else:
  print("Неравенство неверно, а меньше б")

print(a >= b)
if a >= b:
  print("Неравенство верно, а больше или равняется б")
else:
  print("Неравенство неверно, а меньше б")

print(a != b)
if a != b:
  print("Неравенство верно, а не равняется б")
else:
  print("Неравенство неверно, а равняется б")

print(a == b)
if a == b:
  print("Неравенство верно, а равняется б")
else:
  print("Неравенство неверно, а не равняется б")


# --------------
# Пример вывода:
#
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False
# Out:
# a = 2
# b = 3
# Сумма = 5
# Разность = -1
# Произведение = 6
# Частное = 0.67
# Деление нацело = 0
# Остаток от деления = 2
# True
# Неравенство верно, а меньше б
# True
# Неравенство верно, а меньше или равняется б
# False
# Неравенство неверно, а меньше б
# False
# Неравенство неверно, а меньше б
# True
# Неравенство верно, а не равняется б
# False
# Неравенство неверно, а не равняется б

# %%
# Задание task_01_02.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

import math

x = int(input("x = "))
y = int(input("y = "))
z = int(input("z = "))

res = (math.pow(((x ** 5) + 7)/(abs(-6) * y), 1/3)/(7 - z%((y))))
print(round(res, 2))

# --------------
# Пример вывода:
#
# x=0
# y=1
# z=2
# 0.15
# Out:
# x = 0
# y = 1
# z = 2
# 0.15

# %%
# Задание task_01_03.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

r1 = float(input("Введите сопротивление первого проводника: "))
r2 = float(input("Введите сопротивление второго проводника: "))

r = r1 + r2
r = round(r, 1)
# Вывод результата с округлением до 1 знака после запятой
print(f"Общее сопротивление цепи:", r)
# Out:
# Введите сопротивление первого проводника: 10
# Введите сопротивление второго проводника: 20
# Общее сопротивление цепи: 30.0

# %%
# Задание task_01_04.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

num2 = int(input("Введите двузначное число! "))
num3 = int(input("Введите трехзначное число! "))

num2_1 = num2//10
num2_2 = num2%10
num2_s  = num2_1 +num2_2
num2_p = num2_1 *num2_2
print("Сумма цифра вашего двузначного числа:", num2_s)
print("Произведение цифра вашего двузначного числа:", num2_p)

num3_1 = y//100
num3_2 = num3%100
num3_2 = num3_2//10
num3_3 = num3%10
num3_s = num3_1+num3_2+num3_3
num3_p = num3_1*num3_2*num3_3
print("Сумма цифра вашего трехзначного числа:", num3_s)
print("Произведение цифра вашего трехзначного числа:", num3_p)
# Out:
# Введите двузначное число! 35
# Введите трехзначное число! 125
# Сумма цифра вашего двузначного числа: 8
# Произведение цифра вашего двузначного числа: 15
# Сумма цифра вашего трехзначного числа: 16
# Произведение цифра вашего трехзначного числа: 90

# %%
# Задание task_01_05.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

m = int(input("Введите кол-во минут не превашающее значение 1440! "))

print(m)
print("Количество часов, прошедших с начала суток:", m//60)
print("Количество минут, прошедших с момента начала последнего часа:", m%60)
# Out:
# Введите кол-во минут не превашающее значение 1440! 100
# 100
# Количество часов, прошедших с начала суток: 1
# Количество минут, прошедших с момента начала последнего часа: 40

# %%
# Задание task_01_06.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

a = int(input("Введите коэфециент а: "))
b = int(input("Введите коэфециент b: "))
m = int(input("Введите левую границу отрезка: "))
n = int(input("Введите правую границу отрезка: "))

x = -b / a

is_ok = m <= x <= n
print(is_ok)
# Out:
# Введите коэфециент а: 1
# Введите коэфециент b: 2
# Введите левую границу отрезка: 0
# Введите правую границу отрезка: 5
# False

# %%
# Задание task_01_07.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

team = input("Введите название команды: ")
print(f"{team} - чемпион!")
print("-" * len(team))

team_lowercase = team.lower()
print(team_lowercase)
print(len(team))
has_p = "п" in team_lowercase
print(has_p)
count_a = team_lowercase.count("а")
print(count_a)
# Out:
# Введите название команды: ПАПАРАЦИИ
# ПАПАРАЦИИ - чемпион!
# ---------
# папарации
# 9
# True
# 3

# %%
# Задание task_01_08.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

country = input("Введите название государства: ")
capital = input("Введите название столицы: ")

print(f"Государство - {country}, столица - {capital}")
# Out:
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия, столица - Москва

# %%
# Задание task_01_09.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

word = "объектно-ориентированный"
w1 = word[:6]
w2 = word[9:17]
w3 = word[14:17]
w4 = word[4] + word[7] + word[14]
w5 = word[10] + word[12] + word[13] + word[14] + word[19]

print(w1, w2, w3, w4, w5, sep="\n")
# Out:
# объект
# ориентир
# тир
# кот
# рента

# %%
# Задание task_01_10.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

# Создать 2 пустых списка
a = []
b = []

# Добавить 2 вещественных числа (4.5 и 3.4) в список 'a' с помощью append
a.append(4.5)
a.append(3.4)
# Добавить 2 вещественных числа (8.7, 1.3) в список 'a' с помощью extend
a.extend([8.7, 1.3])

# Добавить 2 вещественных числа (14.5, 3.4) в список 'b' с помощью append
b.append(14.5)
b.append(3.4)

# Добавить 2 вещественных числа (8.7, 11.3) в список 'b'с помощью extend
b.extend([8.7, 11.3])

# Вставить целое число 100 на 2-е и 4-е место списка 'a'
a.insert(1, 100)
a.insert(3, 100)

# Вставить целое число 200 на 1-е и 3-е место списка 'b'
b.insert(0, 200)
b.insert(2, 200)

# Вывести списки на экран
print("Исходные списки:")
print("1-й:", a)
print("2-й:", b)

# Удалить первые элементы из списков 'a' и 'b'
del a[0]
del b[0]

# Удалить элемент 100 из списка 'a'
a.remove(100)
# Удалить элемент 200 из списка 'b'
b.remove(200)

# Вывести списки на экран
print("\nПосле удалений:")
print("1-й:", a)
print("2-й:", b)

# Создать множества из списков 'a' и 'b', а также их пересечение
sa = set(a)
sb = set(b)
sa_and_sb = sa & sb

# Вывести экран уникальные элементы каждого списка и общие
print("\nУникальные элементы:")
print("1-й:", sa)
print("2-й:", sb)
print("общие:", sa_and_sb)

# Соединить списки 'a' и 'b'
c = a + b

# Отсортировать список 'c' по возрастанию и убыванию
c_asc = sorted(c)
c_desc = sorted(c, reverse=True)

# Среднее арифметическое элементов списка 'c', расположенных на четных местах
sr_ar = sum(c[1::2]) / len(c[1::2])
# Среднее геометрическое элементов списка 'c', расположенных на нечетных местах
from math import prod
sr_geom = prod(c[::2]) ** (1 / len(c[::2]))

# Максимальный и минимальный элементы
c_max = max(c)
c_min = min(c)

# Вывести результаты на экран
print("\nИтоговые:")
print("3-й:", c)
print("Сортировка (возр.):", c_asc)
print("Сортировка (убыв.):", c_desc)
print(f"Ср. арифм. = {sr_ar:.2f}, ср. геометр. = {sr_geom :.2f}")
print(f"Макс. и мин.: {c_max} {c_min}")
# Out:
# Исходные списки:
# 1-й: [4.5, 100, 3.4, 100, 8.7, 1.3]
# 2-й: [200, 14.5, 200, 3.4, 8.7, 11.3]
#
# После удалений:
# 1-й: [3.4, 100, 8.7, 1.3]
# 2-й: [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# 1-й: {8.7, 1.3, 3.4, 100}
# 2-й: {8.7, 11.3, 3.4, 14.5}
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# Сортировка (возр.): [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# Сортировка (убыв.): [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# Ср. арифм. = 29.00, ср. геометр. = 7.82
# Макс. и мин.: 100 1.3

# %%
# Задание task_01_11.
#
# Выполнил: Миленин И.Д.
# Группа: АБП-231

# В данной задаче все значения задаются в коде (без input())

# 1. Создание словаря
# Создать пустой словарь
info = {}

# Добавить значения для ключей "фио", "дата_рождения", "место_рождения"
info["фио"] = "Миленин Илья Денисович"
info["дата_рождения"] = "26/03/2004"
info["место_рождения"] = "Москва"

# Напечатать словарь
print(info)

# Создать ключ "хобби" со значением = список из строк -
# наименований хобби (например "плавание" и т.д.)
info["хобби"] = ["внеучебка", "аниме"]

# Добавить "программирование" в список хобби
info["хобби"].append("программирование")

# Создать ключ "животные" со значением = кортеж из строк -
# имен домашних животных (например "кошка Мурка" и т.д.)
info["животные"] = ("кот Вован",)

# Создать ключ "ЕГЭ" и поместить в него пустой словарь
info["ЕГЭ"] = {}

# В словарь info["ЕГЭ"] добавить информацию о сданных экзаменах,
# где ключ - наименование предмета, а значение - количество баллов
info["ЕГЭ"]["Математика"] = 72
info["ЕГЭ"]["Информатика"] = 48
info["ЕГЭ"]["Русский язык"] = 70

# Добавить экзамен, который не был сдан, после чего удалить его
info["ЕГЭ"]["Физика"] = 0
del info["ЕГЭ"]["Физика"]

# Создать ключ "вузы" и поместить в него пустой словарь
info["вузы"] = {}

# В словарь info["вузы"] добавить информацию о вузах,
# где ключ - аббревиатура вуза, а значение -
# количество баллов для специальности, на которую хотели поступить
info["вузы"]["МИРЭА"] = 240
info["вузы"]["МГУ"] = 295
info["вузы"]["МГТУ им. Баумана"] = 255

# 2. Вывод на экран
print("Данные:")
# Получившийся словарь
print(info)

# Список экзаменов ЕГЭ в алфавитном порядке
# (используйте метод ``keys()``, преобразовав результат в кортеж)
exams = tuple(sorted(info["ЕГЭ"].keys()))
print("Предметы:", ", ".join(exams))
# Список вузов в алфавитном порядке
uni = tuple(sorted(info["вузы"].keys()))
print("Вузы:", ", ".join(uni))

# 3. Ответы на вопросы
print("\nОтветы на вопросы:")

# Выделить имя из info["фио"]
name = info["фио"].split()[1]
# Начинается на гласную? (True/False)
starts_with_vowel = name[0].lower() in 'аеёиоуыэюя'
print("* мое имя начинается на гласную букву:", starts_with_vowel)

# Выделить месяц из info["дата_рождения"]
month = int(info["дата_рождения"].split('/')[1])
# Родился зимой или летом? (True/False)
born_in_winter_or_summer = month in [12, 1, 2, 6, 7, 8]
print("* родился летом или зимой:", born_in_winter_or_summer)

# Количество хобби и первое из них
hobbies_count = len(info["хобби"])
print("* у меня {} хобби, первое \"{}\"".format(hobbies_count, info["хобби"][0]))

# Количество сданных экзаменов
print("* после окончания школы сдавал {} экз.".format(len(info["ЕГЭ"])))

# Сумма баллов по экзаменам
sum_mark = sum(info["ЕГЭ"].values())
print("* сумма баллов = {}".format(sum_mark))

# Максимальный балл среди сданных
max_mark = max(info["ЕГЭ"].values())
print("* макс. балл = {}".format(max_mark))

# Количество вузов, в которые Вы проходите по баллам
vuz_count = sum(int(sum_mark >= score) for score in info["вузы"].values())
print("* кол-во вузов в которые прохожу: {}".format(vuz_count))
# Out:
# {'фио': 'Миленин Илья Денисович', 'дата_рождения': '26/03/2004', 'место_рождения': 'Москва'}
# Данные:
# {'фио': 'Миленин Илья Денисович', 'дата_рождения': '26/03/2004', 'место_рождения': 'Москва', 'хобби': ['внеучебка', 'аниме', 'программирование'], 'животные': ('кот Вован',), 'ЕГЭ': {'Математика': 72, 'Информатика': 80, 'Русский язык': 70}, 'вузы': {'МИРЭА': 240, 'МГУ': 295, 'МГТУ им. Баумана': 255}}
# Предметы: Информатика, Математика, Русский язык
# Вузы: МГТУ им. Баумана, МГУ, МИРЭА
#
# Ответы на вопросы:
# * мое имя начинается на гласную букву: True
# * родился летом или зимой: False
# * у меня 3 хобби, первое "внеучебка"
# * после окончания школы сдавал 3 экз.
# * сумма баллов = 222
# * макс. балл = 80
# * кол-во вузов в которые прохожу: 0
